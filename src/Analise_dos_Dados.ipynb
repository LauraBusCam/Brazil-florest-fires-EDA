# %% [markdown]
# # Queimadas nas florestas brasileiras - 2012 a 2016

# %% [markdown]
# ## Projeto Final - Técnicas de Programação I

# %% [markdown]
# ### Integrantes
#
# - Glaydson Gonçalo
# - Guilherme Araújo Mendes de Souza
# - Laura Busin Campos
# - Miller M Monteiro

# %% [markdown]
# ### Bases utilizadas
# - **Queimadas:** https://dados.gov.br/dados/conjuntos-dados/snif
# - **Informações do clima:** https://www.kaggle.com/datasets/fabiojorge/brazil-temperature-2012-2019 (separada em duas partes)
#
# <sub>**Observação**: Devido aos seus tamanhos, as bases com informações do clima foram convertidas do formato .csv para o .parquet para que conseguíssemos subí-las no github</sub>

# %% [markdown]
# ### Tratamento dos dados

# %% [markdown]
# #### Bibliotecas

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# #### Sigla dos estados

# %%
sigla_dos_estados = {
    'Acre': 'AC', 'Alagoas': 'AL', 'Amapa': 'AP', 'Amazonas': 'AM', 
    'Bahia': 'BA', 'Ceara': 'CE', 'Distrito Federal': 'DF', 'Espirito Santo': 'ES', 
    'Goias': 'GO', 'Maranhao': 'MA', 'Mato Grosso': 'MT', 'Mato Grosso do Sul': 'MS', 
    'Minas Gerais': 'MG', 'Para': 'PA', 'Paraiba': 'PB', 'Parana': 'PR', 
    'Pernambuco': 'PE', 'Piaui': 'PI', 'Rio de Janeiro': 'RJ', 'Rio Grande do Norte': 'RN', 
    'Rio Grande do Sul': 'RS', 'Rondonia': 'RO', 'Roraima': 'RR', 'Santa Catarina': 'SC', 
    'Sao Paulo': 'SP', 'Sergipe': 'SE', 'Tocantins': 'TO'
}

# %% [markdown]
# #### Meses do ano

# %%
meses_ano = {
    'Janeiro': 1, 'Fevereiro': 2, 'Março': 3, 'Abril': 4, 'Maio': 5, 'Junho': 6, 
    'Julho': 7, 'Agosto': 8, 'Setembro': 9, 'Outubro': 10, 'Novembro': 11, 'Dezembro': 12
}

# %% [markdown]
# #### Leitura dos dados

# %%
df_amazon = pd.read_csv('../Data/amazon.csv', encoding='ISO-8859-1', thousands = '.', sep = ';')
df_data_p1 = pd.read_parquet('../Data/output_data_part1.parquet')
df_data_p2 = pd.read_parquet('../Data/output_data_part2.parquet')

# %%
df_amazon
# Out:
#       year      state     month  number        date
# 0     1998       Acre   Janeiro       0  01/01/1998
# 1     1999       Acre   Janeiro       0  01/01/1999
# 2     2000       Acre   Janeiro       0  01/01/2000
# 3     2001       Acre   Janeiro       0  01/01/2001
# 4     2002       Acre   Janeiro       0  01/01/2002
# ...    ...        ...       ...     ...         ...
# 6449  2012  Tocantins  Dezembro     128  01/01/2012
# 6450  2013  Tocantins  Dezembro      85  01/01/2013
# 6451  2014  Tocantins  Dezembro     223  01/01/2014
# 6452  2015  Tocantins  Dezembro     373  01/01/2015
# 6453  2016  Tocantins  Dezembro     119  01/01/2016
#
# [6454 rows x 5 columns]

# %% [markdown]
# #### Pré-vizualização dos dados

# %%
df_amazon.head()
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro       0  01/01/1998
# 1  1999  Acre  Janeiro       0  01/01/1999
# 2  2000  Acre  Janeiro       0  01/01/2000
# 3  2001  Acre  Janeiro       0  01/01/2001
# 4  2002  Acre  Janeiro       0  01/01/2002

# %%
df_amazon.tail()
# Out:
#       year      state     month  number        date
# 6449  2012  Tocantins  Dezembro     128  01/01/2012
# 6450  2013  Tocantins  Dezembro      85  01/01/2013
# 6451  2014  Tocantins  Dezembro     223  01/01/2014
# 6452  2015  Tocantins  Dezembro     373  01/01/2015
# 6453  2016  Tocantins  Dezembro     119  01/01/2016

# %%
df_data_p1.head()
# Out:
#    CodigoOMM  NomeEstacao Estado EstadoDesc EstadoRegiao  Latitude  Longitude  \
# 0      82989  AGUA BRANCA     AL    Alagoas     Nosdeste     -9.28      -37.9
# 1      82989  AGUA BRANCA     AL    Alagoas     Nosdeste     -9.28      -37.9
# 2      82989  AGUA BRANCA     AL    Alagoas     Nosdeste     -9.28      -37.9
# 3      82989  AGUA BRANCA     AL    Alagoas     Nosdeste     -9.28      -37.9
# 4      82989  AGUA BRANCA     AL    Alagoas     Nosdeste     -9.28      -37.9
#
#    Altitude  EstacaoStituacao OperanteDesde  ...  UmidadeRelativa  \
# 0    605.34  Estação Operante    05/05/1928  ...             91.0
# 1    605.34  Estação Operante    05/05/1928  ...             88.0
# 2    605.34  Estação Operante    05/05/1928  ...             89.0
# 3    605.34  Estação Operante    05/05/1928  ...             82.0
# 4    605.34  Estação Operante    05/05/1928  ...             90.0
#
#   PressaoAtmEstacao  PressaoAtmMar  DirecaoVento  VelocidadeVentoInsolacao  \
# 0             943.6         1010.2          14.0                       7.0
# 1             945.7         1012.3           5.0                       5.0
# 2             943.7         1010.1          14.0                       5.0
# 3             944.5         1010.8           5.0                       7.0
# 4             942.7         1008.7          14.0                       5.0
#
#    Nebulosidade  Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 0          11.3               0.0              7.8                   25.92
# 1           NaN               1.0              NaN                     NaN
# 2          10.5               0.0              8.4                   27.26
# 3           NaN               3.0              NaN                     NaN
# 4           8.9               0.0             10.5                   26.68
#
#    Velocidade do Vento Media
# 0                       89.0
# 1                        NaN
# 2                       87.0
# 3                        NaN
# 4                       87.0
#
# [5 rows x 28 columns]

# %%
df_data_p2.head()
# Out:
#    CodigoOMM NomeEstacao Estado EstadoDesc EstadoRegiao  Latitude  Longitude  \
# 0      82791       PATOS     PB    Paraiba     Nordeste     -7.01     -37.26
# 1      82791       PATOS     PB    Paraiba     Nordeste     -7.01     -37.26
# 2      82791       PATOS     PB    Paraiba     Nordeste     -7.01     -37.26
# 3      82791       PATOS     PB    Paraiba     Nordeste     -7.01     -37.26
# 4      82791       PATOS     PB    Paraiba     Nordeste     -7.01     -37.26
#
#    Altitude  EstacaoStituacao OperanteDesde  ...  UmidadeRelativa  \
# 0    249.09  Estação Operante    17/10/1975  ...             53.0
# 1    249.09  Estação Operante    17/10/1975  ...             56.0
# 2    249.09  Estação Operante    17/10/1975  ...             33.0
# 3    249.09  Estação Operante    17/10/1975  ...             58.0
# 4    249.09  Estação Operante    17/10/1975  ...             60.0
#
#   PressaoAtmEstacao  PressaoAtmMar  DirecaoVento  VelocidadeVentoInsolacao  \
# 0             981.5         1008.9           9.0                       4.8
# 1             985.3         1012.9           9.0                       4.5
# 2             980.2         1007.6          14.0                       3.3
# 3             982.3         1008.3           5.0                       4.8
# 4             985.0         1012.6           5.0                       3.0
#
#    Nebulosidade  Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 0          11.3               0.0             13.0                   30.24
# 1           NaN               7.0              NaN                     NaN
# 2           NaN               6.0              NaN                     NaN
# 3          10.5               9.0              9.1                   29.34
# 4           NaN               7.0              NaN                     NaN
#
#    Velocidade do Vento Media
# 0                      51.25
# 1                        NaN
# 2                        NaN
# 3                      56.75
# 4                        NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Tratamento do campo date do df_amazon que mostra sempre ano-01-01 independentemente do mês

# %%
df_amazon = df_amazon.rename(columns={'month': 'mes', 'year': 'ano'})
df_amazon['date'] = pd.to_datetime(df_amazon['date'])

# %%
df_amazon['day'] = df_amazon['date'].dt.day
df_amazon['month'] = df_amazon['date'].dt.month
df_amazon['year'] = df_amazon['date'].dt.year

# %%
df_amazon['month'] = [meses_ano[mes] for mes in df_amazon['mes']]

# %%
df_amazon['date'] = pd.to_datetime(df_amazon[['year', 'month', 'day']])

# %%
df_amazon = df_amazon.drop(['day', 'month', 'year'], axis=1)
df_amazon = df_amazon.rename(columns={'mes': 'month', 'ano': 'year'})

# %% [markdown]
# #### Padronização das datas

# %%
df_data_p1['Data'] = pd.to_datetime(df_data_p2['Data'], format='%d/%m/%Y', errors='coerce')
df_data_p2['Data'] = pd.to_datetime(df_data_p2['Data'], format='%d/%m/%Y', errors='coerce')

# %%
df_amazon['date'] = pd.to_datetime(df_amazon['date'])
df_amazon['date'] = pd.to_datetime(df_amazon['date'], format='%d/%m/%Y')

# %%
df_data_p1['Data'] = pd.to_datetime(df_data_p1['Data'])
df_data_p1['Data'] = pd.to_datetime(df_data_p1['Data'], format='%d/%m/%Y')

# %%
df_data_p2['Data'] = pd.to_datetime(df_data_p2['Data'])
df_data_p2['Data'] = pd.to_datetime(df_data_p2['Data'], format='%d/%m/%Y')

# %% [markdown]
# #### Filtragem dos DF´s

# %%
df_amazon = df_amazon[(df_amazon['date'] <= pd.Timestamp(year=2016, month=12, day=31)) & (df_amazon['date'] >= pd.Timestamp(year=2012, month=1, day=1))]

df_data_p1 = df_data_p1[(df_data_p1['Data'] <= pd.Timestamp(year=2016, month=12, day=31)) & (df_data_p1['Data'] >= pd.Timestamp(year=2012, month=1, day=1))]

df_data_p2 = df_data_p2[(df_data_p2['Data'] <= pd.Timestamp(year=2016, month=12, day=31)) & (df_data_p2['Data'] >= pd.Timestamp(year=2012, month=1, day=1))]

# %% [markdown]
# #### Concatenação dos dataframe df_data_p1 e df_data_p2

# %%
df_data = pd.concat([df_data_p1, df_data_p2], ignore_index=True)

# %%
filtro = df_data[['Estado', 'EstadoDesc', 'Data', 'Precipitacao', 'TempMaxima', 'TempMinima', 'UmidadeRelativa']]

# %%
media_mensal = filtro.groupby(['Estado', 'EstadoDesc', pd.Grouper(key='Data', freq='M')]).mean()

media_mensal = media_mensal.reset_index()

# %% [markdown]
# #### Concatenação dos dataframe media_mensal e df_amazon

# %%
df_amazon.rename(columns={'state': 'EstadoDesc', 'date': 'Data', 'year': 'Ano'}, inplace=True)

# %%
df_amazon['Data'] = pd.to_datetime(df_amazon['Data'])
media_mensal['Data'] = pd.to_datetime(media_mensal['Data'])

# %%
df_amazon['AnoMes'] = df_amazon['Data'].dt.to_period('M')

media_mensal['AnoMes'] = media_mensal['Data'].dt.to_period('M')

# %%
df_amazon['Estado'] = [sigla_dos_estados[estado] for estado in df_amazon['EstadoDesc']]

# %%
df = pd.merge(df_amazon, media_mensal, on=['Estado', 'AnoMes'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1474 entries, 0 to 1473
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ano              1474 non-null   int64
#  1   EstadoDesc_x     1474 non-null   object
#  2   month            1474 non-null   object
#  3   number           1474 non-null   int64
#  4   Data_x           1474 non-null   datetime64[ns]
#  5   AnoMes           1474 non-null   period[M]
#  6   Estado           1474 non-null   object
#  7   EstadoDesc_y     1474 non-null   object
#  8   Data_y           1474 non-null   datetime64[ns]
#  9   Precipitacao     1474 non-null   float64
#  10  TempMaxima       1459 non-null   float64
#  11  TempMinima       1453 non-null   float64
#  12  UmidadeRelativa  1474 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(4), period[M](1)
# memory usage: 161.2+ KB

# %% [markdown]
# #### Organizando os nomes e as colunas do df

# %%
df.drop(['Data_x', 'Data_y', 'EstadoDesc_y'], axis=1, inplace=True)

# %%
df.rename(columns={'EstadoDesc_x': 'EstadoDesc', 'number': 'QtQueimadas', 'month': 'Mes'}, inplace=True)

# %%
df = df[['AnoMes', 'Ano', 'Mes', 'EstadoDesc', 'Estado', 'QtQueimadas', 'Precipitacao', 'TempMaxima', 'TempMinima', 'UmidadeRelativa']]

# %% [markdown]
# #### Tratamento dos nulos

# %%
df.isnull().sum()
# Out:
# AnoMes              0
# Ano                 0
# Mes                 0
# EstadoDesc          0
# Estado              0
# QtQueimadas         0
# Precipitacao        0
# TempMaxima         15
# TempMinima         21
# UmidadeRelativa     0
# dtype: int64

# %%
df[df['TempMaxima'].isnull()]
# Out:
#       AnoMes   Ano        Mes          EstadoDesc Estado  QtQueimadas  \
# 604  2016-01  2016    Janeiro  Mato Grosso do Sul     MS          127
# 609  2016-02  2016  Fevereiro  Mato Grosso do Sul     MS          187
# 637  2015-09  2015   Setembro  Mato Grosso do Sul     MS         1482
# 645  2015-11  2015   Novembro  Mato Grosso do Sul     MS          276
# 649  2015-12  2015   Dezembro  Mato Grosso do Sul     MS          394
# 830  2012-01  2012    Janeiro              Parana     PR           31
# 831  2013-01  2013    Janeiro              Parana     PR           28
# 834  2012-02  2012  Fevereiro              Parana     PR           40
# 835  2013-02  2013  Fevereiro              Parana     PR            9
# 837  2012-03  2012      Março              Parana     PR           55
# 840  2012-04  2012      Abril              Parana     PR           38
# 858  2012-09  2012   Setembro              Parana     PR          459
# 862  2012-10  2012    Outubro              Parana     PR          145
# 866  2012-11  2012   Novembro              Parana     PR          142
# 870  2012-12  2012   Dezembro              Parana     PR           54
#
#      Precipitacao  TempMaxima  TempMinima  UmidadeRelativa
# 604      6.580645         NaN         NaN        76.612903
# 609     15.200000         NaN         NaN        96.000000
# 637      6.820000         NaN         NaN        68.811111
# 645      9.310000         NaN    9.400000        80.744444
# 649     12.480645         NaN         NaN        81.440860
# 830      3.965079         NaN   11.722222        87.740741
# 831      4.837333         NaN    8.913333        91.718232
# 834      7.793506         NaN   10.903896        85.146552
# 835      3.570930         NaN    9.560465        88.536697
# 837      4.087952         NaN   12.233735        82.919355
# 840      3.355000         NaN   13.170000        80.191667
# 858      6.001250         NaN   18.311250        85.350000
# 862      7.247778         NaN   17.488889        87.827869
# 866      3.505495         NaN   16.700000        86.495726
# 870      4.610526         NaN   10.727368        88.078838

# %%
df[df['TempMinima'].isnull()]
# Out:
#       AnoMes   Ano        Mes          EstadoDesc Estado  QtQueimadas  \
# 603  2015-01  2015    Janeiro  Mato Grosso do Sul     MS          226
# 604  2016-01  2016    Janeiro  Mato Grosso do Sul     MS          127
# 608  2015-02  2015  Fevereiro  Mato Grosso do Sul     MS          148
# 609  2016-02  2016  Fevereiro  Mato Grosso do Sul     MS          187
# 612  2014-03  2014      Março  Mato Grosso do Sul     MS           95
# 613  2015-03  2015      Março  Mato Grosso do Sul     MS          190
# 616  2014-04  2014      Abril  Mato Grosso do Sul     MS          129
# 620  2014-05  2014       Maio  Mato Grosso do Sul     MS           70
# 621  2015-05  2015       Maio  Mato Grosso do Sul     MS           58
# 624  2014-06  2014      Junho  Mato Grosso do Sul     MS           84
# 625  2015-06  2015      Junho  Mato Grosso do Sul     MS          299
# 629  2015-07  2015      Julho  Mato Grosso do Sul     MS          371
# 632  2014-08  2014     Agosto  Mato Grosso do Sul     MS          312
# 633  2015-08  2015     Agosto  Mato Grosso do Sul     MS         1293
# 636  2014-09  2014   Setembro  Mato Grosso do Sul     MS          365
# 637  2015-09  2015   Setembro  Mato Grosso do Sul     MS         1482
# 640  2014-10  2014    Outubro  Mato Grosso do Sul     MS          581
# 641  2015-10  2015    Outubro  Mato Grosso do Sul     MS          507
# 644  2014-11  2014   Novembro  Mato Grosso do Sul     MS          190
# 648  2014-12  2014   Dezembro  Mato Grosso do Sul     MS           84
# 649  2015-12  2015   Dezembro  Mato Grosso do Sul     MS          394
#
#      Precipitacao  TempMaxima  TempMinima  UmidadeRelativa
# 603      5.933871   35.950000         NaN        71.367568
# 604      6.580645         NaN         NaN        76.612903
# 608      4.894643   35.692857         NaN        77.297619
# 609     15.200000         NaN         NaN        96.000000
# 612      6.256452   35.038710         NaN        73.306452
# 613      5.951613   33.493548         NaN        78.215054
# 616      4.640000   35.188462         NaN        74.255682
# 620      3.748485   34.659375         NaN        79.741758
# 621      8.056452   32.856250         NaN        82.994595
# 624      4.366176   31.713889         NaN        80.034884
# 625      2.342424   32.737838         NaN        80.837079
# 629      3.835211   27.667500         NaN        85.000000
# 632      1.487097   28.503226         NaN        74.564516
# 633      0.487879   28.200000         NaN        64.731959
# 636      4.075000   28.400000         NaN        71.533708
# 632      1.487097   28.503226         NaN        74.564516
# 633      0.487879   28.200000         NaN        64.731959
# 636      4.075000   28.400000         NaN        71.533708
# 637      6.820000         NaN         NaN        68.811111
# 640      1.159677   29.654839         NaN        58.335135
# 641      4.403226   28.900000         NaN        75.870968
# 644      5.358333   33.373333         NaN        65.127778
# 645      9.310000         NaN    9.400000        80.744444
# 648      2.682258   34.716667         NaN        70.841530
# 649     12.480645         NaN         NaN        81.440860
# 830      3.965079         NaN   11.722222        87.740741
# 831      4.837333         NaN    8.913333        91.718232
# 834      7.793506         NaN   10.903896        85.146552
# 835      3.570930         NaN    9.560465        88.536697
# 837      4.087952         NaN   12.233735        82.919355
# 840      3.355000         NaN   13.170000        80.191667
# 858      6.001250         NaN   18.311250        85.350000
# 862      7.247778         NaN   17.488889        87.827869
# 866      3.505495         NaN   16.700000        86.495726
# 870      4.610526         NaN   10.727368        88.078838

# %%
estados_nan = list(missing['Estado'].unique())

# %%
df = df.loc[~df['Estado'].isin(estados_nan)]

# %%
df.isnull().sum()
# Out:
# AnoMes             0
# Ano                0
# Mes                0
# EstadoDesc         0
# Estado             0
# QtQueimadas        0
# Precipitacao       0
# TempMaxima         0
# TempMinima         0
# UmidadeRelativa    0
# dtype: int64

# %%
df
# Out:
#        AnoMes   Ano       Mes EstadoDesc Estado  QtQueimadas  Precipitacao  \
# 0     2012-01  2012   Janeiro       Acre     AC            0     12.301205
# 1     2013-01  2013   Janeiro       Acre     AC            0     12.518293
# 2     2014-01  2014   Janeiro       Acre     AC            0     14.368605
# 3     2015-01  2015   Janeiro       Acre     AC            1      9.286735
# 4     2016-01  2016   Janeiro       Acre     AC           12      6.346552
# ...       ...   ...       ...        ...    ...          ...           ...
# 1469  2012-12  2012  Dezembro  Tocantins     TO          128      3.070115
# 1470  2013-12  2013  Dezembro  Tocantins     TO           85     10.491558
# 1471  2014-12  2014  Dezembro  Tocantins     TO          223      7.704575
# 1472  2015-12  2015  Dezembro  Tocantins     TO          373      3.761290
# 1473  2016-12  2016  Dezembro  Tocantins     TO          119      7.254032
#
#       TempMaxima  TempMinima  UmidadeRelativa
# 0      30.414286   22.554217        88.350598
# 1      31.443210   22.786585        87.516393
# 2      30.718391   22.663953        88.934615
# 3      31.155102   22.351546        89.455253
# 4      32.463793   23.993103        90.048276
# ...          ...         ...              ...
# 1469   34.549655   21.601379        65.643969
# 1470   31.443137   21.609804        76.061947
# 1471   32.221488   22.277778        75.348214
# 1472   35.112931   23.354839        65.100559
# 1473   33.349194   22.752419        71.754144
#
# [1380 rows x 10 columns]

# %% [markdown]
# ### Análises estatísticas

# %% [markdown]
# #### Estatística Descritiva

# %%
desc_stats = df.describe()

desc_stats
# Out:
#                Ano   QtQueimadas  Precipitacao   TempMaxima   TempMinima  \
# count  1380.000000   1380.000000   1380.000000  1380.000000  1380.000000
# mean   2014.000000    589.486232      3.778830    30.946977    20.270155
# std       1.414726   1411.360553      2.635092     3.300272     3.239892
# min    2012.000000      0.000000      0.000000    18.554637     8.593250
# 25%    2013.000000     19.000000      1.749781    29.349728    18.431210
# 50%    2014.000000     75.000000      3.163326    31.695385    21.118054
# 75%    2015.000000    348.000000      5.451222    33.195998    22.843315
# max    2016.000000  11068.000000     15.304839    37.592126    25.540678
#
#        UmidadeRelativa
# count      1380.000000
# mean         71.471661
# std           9.083527
# min          42.322581
# 25%          66.036456
# 50%          71.927778
# 75%          77.891804
# max          90.577206

# %% [markdown]
# ##### Por estado

# %%
desc_stats_queimada = df[['Estado', 'QtQueimadas']].groupby('Estado').describe()

# Ordenando pelas maiores médias
desc_stats_queimada['QtQueimadas'].sort_values(by = 'mean', ascending = False)
# Out:
#         count         mean          std    min     25%     50%      75%  \
# Estado
# PA       60.0  2583.266667  3184.037283   11.0   78.25   581.5  5011.00
# MT       60.0  2239.900000  2636.478196  166.0  536.00  1072.5  2378.50
# MA       60.0  2002.166667  2353.865347    5.0  117.50   901.0  3587.50
# TO       60.0  1201.816667  1576.428601    4.0  111.50   459.0  1722.50
# BA       60.0   959.366667  1622.714079  107.0  197.50   316.0   750.25
# PI       60.0   897.633333  1241.964204   14.0   71.75   353.5  1200.00
# AM       60.0   822.400000  1308.405981    3.0   34.50   171.0  1074.75
# MG       60.0   751.383333  1115.845793   61.0  131.25   203.5   920.25
# GO       60.0   462.050000   608.834325   21.0   84.50   180.0   551.25
# AC       60.0   379.283333   789.877680    0.0    2.00    12.5   280.50
# CE       60.0   288.250000   392.345689    2.0   17.00    75.0   478.75
# SP       60.0   235.833333   281.222463   21.0   68.75   115.0   236.50
# RR       60.0   157.066667   271.941847    0.0   12.00    74.0   179.50
# RS       60.0   152.500000   235.781319   10.0   42.75    68.0   118.25
# SC       60.0   107.550000   156.761659    3.0   26.75    45.0    89.00
# PE       60.0    75.433333    79.209734    3.0   12.75    38.0   122.25
# RJ       60.0    64.100000    86.536893    5.0   16.00    30.0    74.00
# ES       60.0    43.900000    51.618450    1.0   15.00    26.5    54.00
# PB       60.0    42.516667    58.013292    0.0    4.75    14.0    62.00
# RN       60.0    30.933333    36.214459    0.0    3.00    14.5    46.25
# AL       60.0    29.000000    36.421729    0.0    4.00    18.0    40.25
# SE       60.0    16.183333    18.994639    0.0    1.00     9.0    27.75
# DF       60.0    15.650000    24.351818    0.0    0.00     2.0    23.25
#
#             max
# Estado
# PA      11068.0
# MT      11068.0
# MA      10395.0
# TO       7461.0
# BA       7956.0
# PI       5828.0
# AM       5882.0
# MG       4735.0
# GO       2452.0
# AC       3586.0
# CE       1328.0
# SP       1458.0
# RR       1754.0
# RS       1168.0
# SC        765.0
# PE        319.0
# RJ        500.0
# ES        307.0
# PB        304.0
# RN        129.0
# AL        162.0
# SE         71.0
# DF         99.0

# %%
desc_stats_chuva = df[['Estado', 'Precipitacao']].groupby('Estado').describe()

# Ordenando pelas maiores médias
desc_stats_chuva['Precipitacao'].sort_values(by = 'mean', ascending = False)
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Estado
# AM       60.0  7.705600  1.927258  4.440517  6.526132  7.621488  8.794331
# PA       60.0  6.404592  2.132227  2.108046  4.999298  6.432737  7.786320
# GO      68.993653  76.947005
# PI      62.517824  72.353503

# %% [markdown]
# ##### Por ano

# %%
desc_ano_umid = df[['Ano', 'QtQueimadas']].groupby('Ano').describe()

# Ordenando pelas maiores médias
desc_ano_umid['QtQueimadas'].sort_values(by = 'mean', ascending = False)
# Out:
#       count        mean          std  min    25%    50%     75%      max
# Ano
# 2015  276.0  767.221014  1819.398190  0.0  25.00   90.5  369.25  11068.0
# 2012  276.0  619.463768  1565.734071  0.0  18.00   71.0  326.00  10395.0
# 2014  276.0  600.847826  1404.145203  0.0  19.75   72.5  334.75   8555.0
# 2016  276.0  590.123188  1213.919458  0.0  21.75  106.0  503.75   8981.0
# 2013  276.0  369.775362   836.973557  0.0  14.00   58.0  239.00   5576.0

# %%
desc_ano_umid = df[['Ano', 'Precipitacao']].groupby('Ano').describe()

# Ordenando pelas maiores médias
desc_ano_umid['Precipitacao'].sort_values(by = 'mean', ascending = False)
# Out:
#       count      mean       std       min       25%       50%       75%  \
# Ano
# 2013  276.0  4.016801  2.821394  0.078607  1.997327  3.301612  5.537403
# 2014  276.0  3.971967  2.479545  0.072348  2.108135  3.368682  5.881983
# 2016  276.0  3.718498  2.657386  0.000000  1.532647  3.315425  5.450491
# 2015  276.0  3.608603  2.584102  0.000000  1.465822  3.157694  5.258701
# 2012  276.0  3.578280  2.608537  0.005333  1.699832  2.705662  4.706015
#
#             max
# Ano
# 2013  15.304839
# 2014  14.368605
# 2016  12.235862
# 2015  12.448171
# 2012  12.301205

# %%
desc_ano_umid = df[['Ano', 'TempMaxima']].groupby('Ano').describe()

# Ordenando pelas maiores médias
desc_ano_umid['TempMaxima'].sort_values(by = 'mean', ascending = False)
# Out:
#       count       mean       std        min        25%        50%        75%  \
# Ano
# 2015  276.0  31.195925  3.358980  20.641129  29.775622  32.028646  33.408982
# 2016  276.0  31.188059  3.385444  18.610606  29.530123  31.823354  33.625570
# 2012  276.0  30.893112  3.209310  19.335904  29.270717  31.449321  33.048488
# 2014  276.0  30.765366  3.143043  19.319274  29.330722  31.549260  32.942261
# 2013  276.0  30.692420  3.387249  18.554637  29.106004  31.682584  32.908319
#
#             max
# Ano
# 2015  37.592126
# 2016  37.145679
# 2012  37.134914
# 2014  36.080682
# 2013  36.396825

# %%
desc_ano_umid = df[['Ano', 'TempMinima']].groupby('Ano').describe()

# Ordenando pelas maiores médias
desc_ano_umid['TempMinima'].sort_values(by = 'mean', ascending = False)
# Out:
#       count       mean       std        min        25%        50%        75%  \
# Ano
# 2016  276.0  20.486568  3.296017   9.377879  18.913522  21.423506  22.962167
# 2015  276.0  20.407922  3.148269  11.092500  18.266505  21.104767  23.032681
# 2014  276.0  20.166467  3.198538  10.946927  18.431210  20.868883  22.709460
# 2013  276.0  20.146259  3.407461   8.593250  18.241000  21.141589  22.720731
# 2012  276.0  20.143561  3.148350   8.970361  18.442606  20.870553  22.630152
#
#             max
# Ano
# 2016  24.755172
# 2015  24.592308
# 2014  24.903846
# 2013  25.540678
# 2012  25.151852

# %%
desc_ano_umid = df[['Ano', 'UmidadeRelativa']].groupby('Ano').describe()

# Ordenando pelas maiores médias
desc_ano_umid['UmidadeRelativa'].sort_values(by = 'mean', ascending = False)
# Out:
#       count       mean       std        min        25%        50%        75%  \
# Ano
# 2014  276.0  72.396250  8.533716  46.232449  67.237300  73.084522  78.752808
# 2013  276.0  71.999538  8.740589  44.614907  66.871928  72.710501  78.811420
# 2015  276.0  71.242420  9.258806  42.503226  66.495968  71.687229  77.482971
# 2012  276.0  71.223647  9.621374  42.322581  65.228813  71.732456  78.375362
# 2016  276.0  70.496449  9.166641  45.029508  65.245804  70.476398  77.277526
#
#             max
# Ano
# 2014  89.309013
# 2013  88.387097
# 2015  90.577206
# 2012  89.720524
# 2016  90.048276

# %% [markdown]
# #### Correlacao

# %%
correlacoes = df[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000    0.851507        -0.328669     -0.165314
# TempMinima         0.851507    1.000000         0.042959      0.069593
# UmidadeRelativa   -0.328669    0.042959         1.000000      0.666902
# Precipitacao      -0.165314    0.069593         0.666902      1.000000
# QtQueimadas        0.267383    0.121732        -0.101210     -0.031963
#
#                  QtQueimadas
# TempMaxima          0.267383
# TempMinima          0.121732
# UmidadeRelativa    -0.101210
# Precipitacao       -0.031963
# QtQueimadas         1.000000

# %% [markdown]
# ##### Correlacao filtrando estados e anos específicos
#
# Foram selecionados um estado de cada região do Brasil (Norte, Nordeste, Centro-Oeste, Sudeste e Sul) e os anos com a maior e menor média de quantidade de incêndios (2013 e 2015)

# %% [markdown]
# ##### Pará (Norte)

# %%
df_pa_2013 = df[(df['Estado'] == 'PA') & (df['Ano'] == 2013)]
df_pa_2015 = df[(df['Estado'] == 'PA') & (df['Ano'] == 2015)]

# %%
correlacoes_pa_2013 = df_pa_2013[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_pa_2013
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000   -0.107753        -0.735734     -0.811710
# TempMinima        -0.107753    1.000000        -0.102172      0.103985
# UmidadeRelativa   -0.735734   -0.102172         1.000000      0.782667
# Precipitacao      -0.811710    0.103985         0.782667      1.000000
# QtQueimadas       -0.169331    0.079012        -0.317950      0.144356
#
#                  QtQueimadas
# TempMaxima         -0.169331
# TempMinima          0.079012
# UmidadeRelativa    -0.317950
# Precipitacao        0.144356
# QtQueimadas         1.000000

# %%
correlacoes_pa_2015 = df_pa_2015[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_pa_2015
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000    0.585680        -0.886874     -0.955665
# TempMinima         0.585680    1.000000        -0.272770     -0.399275
# UmidadeRelativa   -0.886874   -0.272770         1.000000      0.859981
# Precipitacao      -0.955665   -0.399275         0.859981      1.000000
# QtQueimadas        0.526048    0.080125        -0.786935     -0.431701
#
#                  QtQueimadas
# TempMaxima          0.526048
# TempMinima          0.080125
# UmidadeRelativa    -0.786935
# Precipitacao       -0.431701
# QtQueimadas         1.000000

# %%
df_pa_2015.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_pa_2013.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %% [markdown]
# ##### Pernambuco (Nordeste)

# %%
df_pe_2013 = df[(df['Estado'] == 'PE') & (df['Ano'] == 2013)]
df_pe_2015 = df[(df['Estado'] == 'PE') & (df['Ano'] == 2015)]

# %%
correlacoes_pe_2013 = df_pe_2013[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_pe_2013
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000   -0.486630        -0.761762     -0.790732
# TempMinima        -0.486630    1.000000         0.895989      0.705992
# UmidadeRelativa   -0.761762    0.895989         1.000000      0.872731
# Precipitacao      -0.790732    0.705992         0.872731      1.000000
# QtQueimadas        0.705535   -0.389447        -0.618551     -0.356197
#
#                  QtQueimadas
# TempMaxima          0.705535
# TempMinima         -0.389447
# UmidadeRelativa    -0.618551
# Precipitacao       -0.356197
# QtQueimadas         1.000000

# %%
df_pe_2013.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_pe_2013.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_pe_2013.groupby(['AnoMes'])['Precipitacao'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
correlacoes_pe_2015 = df_pe_2015[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_pe_2015
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000   -0.016020        -0.523747      0.021525
# TempMinima        -0.016020    1.000000         0.283305      0.508018
# UmidadeRelativa   -0.523747    0.283305         1.000000      0.351459
# Precipitacao       0.021525    0.508018         0.351459      1.000000
# QtQueimadas        0.800884    0.050247        -0.595231     -0.148476
#
#                  QtQueimadas
# TempMaxima          0.800884
# TempMinima          0.050247
# UmidadeRelativa    -0.595231
# Precipitacao       -0.148476
# QtQueimadas         1.000000

# %%
df_pe_2015.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_pe_2013.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_pe_2013.groupby(['AnoMes'])['TempMaxima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %% [markdown]
# ##### Mato Grosso (Centro-Oeste)

# %%
df_mt_2013 = df[(df['Estado'] == 'MT') & (df['Ano'] == 2013)]
df_mt_2015 = df[(df['Estado'] == 'MT') & (df['Ano'] == 2015)]

# %%
correlacoes_mt_2013 = df_mt_2013[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_mt_2013
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000   -0.486630        -0.761762     -0.790732
# TempMinima        -0.486630    1.000000         0.895989      0.705992
# UmidadeRelativa   -0.761762    0.895989         1.000000      0.872731
# Precipitacao      -0.790732    0.705992         0.872731      1.000000
# QtQueimadas        0.705535   -0.389447        -0.618551     -0.356197
#
#                  QtQueimadas
# TempMaxima          0.705535
# TempMinima         -0.389447
# UmidadeRelativa    -0.618551
# Precipitacao       -0.356197
# QtQueimadas         1.000000

# %%
df_mt_2013.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_mt_2013.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_mt_2013.groupby(['AnoMes'])['TempMaxima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
correlacoes_mt_2015 = df_mt_2015[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_mt_2015
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000   -0.016020        -0.523747      0.021525
# TempMinima        -0.016020    1.000000         0.283305      0.508018
# UmidadeRelativa   -0.523747    0.283305         1.000000      0.351459
# Precipitacao       0.021525    0.508018         0.351459      1.000000
# QtQueimadas        0.800884    0.050247        -0.595231     -0.148476
#
#                  QtQueimadas
# TempMaxima          0.800884
# TempMinima          0.050247
# UmidadeRelativa    -0.595231
# Precipitacao       -0.148476
# QtQueimadas         1.000000

# %%
df_mt_2015.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_mt_2013.groupby(['AnoMes'])['TempMaxima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_mt_2013.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %% [markdown]
# ##### São Paulo (Sudeste)

# %%
df_sp_2013 = df[(df['Estado'] == 'SP') & (df['Ano'] == 2013)]
df_sp_2015 = df[(df['Estado'] == 'SP') & (df['Ano'] == 2015)]

# %%
correlacoes_sp_2013 = df_sp_2013[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_sp_2013
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000    0.812653         0.024812      0.638047
# TempMinima         0.812653    1.000000         0.561522      0.846403
# UmidadeRelativa    0.024812    0.561522         1.000000      0.538009
# Precipitacao       0.638047    0.846403         0.538009      1.000000
# QtQueimadas       -0.040238   -0.509225        -0.913105     -0.452998
#
#                  QtQueimadas
# TempMaxima         -0.040238
# TempMinima         -0.509225
# UmidadeRelativa    -0.913105
# Precipitacao       -0.452998
# QtQueimadas         1.000000

# %%
df_sp_2013.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_sp_2013.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
correlacoes_sp_2015 = df_sp_2015[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_sp_2015
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000    0.762855        -0.466183      0.247367
# TempMinima         0.762855    1.000000         0.083834      0.704229
# UmidadeRelativa   -0.466183    0.083834         1.000000      0.485310
# Precipitacao       0.247367    0.704229         0.485310      1.000000
# QtQueimadas        0.264728   -0.217994        -0.905041     -0.351710
#
#                  QtQueimadas
# TempMaxima          0.264728
# TempMinima         -0.217994
# UmidadeRelativa    -0.905041
# Precipitacao       -0.351710
# QtQueimadas         1.000000

# %%
df_sp_2015.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_sp_2015.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %% [markdown]
# ##### Santa Catarina (Sul)

# %%
df_sc_2013 = df[(df['Estado'] == 'SC') & (df['Ano'] == 2013)]
df_sc_2015 = df[(df['Estado'] == 'SC') & (df['Ano'] == 2015)]

# %%
correlacoes_sc_2013 = df_sc_2013[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_sc_2013
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000    0.923301        -0.729416     -0.233342
# TempMinima         0.923301    1.000000        -0.444622     -0.228139
# UmidadeRelativa   -0.729416   -0.444622         1.000000      0.288329
# Precipitacao      -0.233342   -0.228139         0.288329      1.000000
# QtQueimadas       -0.583539   -0.729679         0.236896      0.347588
#
#                  QtQueimadas
# TempMaxima         -0.583539
# TempMinima         -0.729679
# UmidadeRelativa     0.236896
# Precipitacao        0.347588
# QtQueimadas         1.000000

# %%
df_sc_2013.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_sc_2013.groupby(['AnoMes'])['TempMaxima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_sc_2013.groupby(['AnoMes'])['TempMinima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
correlacoes_sc_2015 = df_sc_2015[['TempMaxima', 'TempMinima', 'UmidadeRelativa', 'Precipitacao', 'QtQueimadas']].corr()
correlacoes_sc_2015
# Out:
#                  TempMaxima  TempMinima  UmidadeRelativa  Precipitacao  \
# TempMaxima         1.000000    0.966920        -0.650665     -0.065963
# TempMinima         0.966920    1.000000        -0.519625      0.085387
# UmidadeRelativa   -0.650665   -0.519625         1.000000      0.369548
# Precipitacao      -0.065963    0.085387         0.369548      1.000000
# QtQueimadas       -0.344138   -0.473527        -0.277208     -0.433888
#
#                  QtQueimadas
# TempMaxima         -0.344138
# TempMinima         -0.473527
# UmidadeRelativa    -0.277208
# Precipitacao       -0.433888
# QtQueimadas         1.000000

# %%
df_sc_2015.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df_sc_2013.groupby(['AnoMes'])['TempMinima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %% [markdown]
# #### Séries Temporais

# %%
df.groupby(['AnoMes'])['QtQueimadas'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df.groupby(['AnoMes'])['TempMaxima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df.groupby(['AnoMes'])['TempMinima'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df.groupby(['AnoMes'])['Precipitacao'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %%
df.groupby(['AnoMes'])['UmidadeRelativa'].mean().plot()
# Out:
# <AxesSubplot: xlabel='AnoMes'>

# %% [markdown]
# #### Análise de Variância

# %%
modelo = ols('QtQueimadas ~ Estado', data=df).fit()
anova_table = sm.stats.anova_lm(modelo, typ=2)

# %%
anova_table
# Out:
#                 sum_sq      df          F        PR(>F)
# Estado    7.613714e+08    22.0  23.652726  3.878474e-80
# Residual  1.985512e+09  1357.0        NaN           NaN
